# %% [markdown]
# <a href="https://colab.research.google.com/github/poisonkissedsk/Computational-Drug-Discovery/blob/main/python/CDD_ML_Part_1_STE20-related%20kinase%20adapter%20protein%20alpha_Bioactivity_Data_Concised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Breast Cancer Proteins**

# %%
# Target search for Breast Cancer
target = new_client.target
target_query = target.search('Breast Cancer')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#     cross_references           organism  \
# 0                 []       Homo sapiens
# 1                 []       Homo sapiens
# 2                 []       Homo sapiens
# 3                 []       Homo sapiens
# 4                 []  Rattus norvegicus
# ..               ...                ...
# 103               []       Homo sapiens
# 104               []       Homo sapiens
# 105               []       Homo sapiens
# 106               []       Homo sapiens
# 107               []       Homo sapiens
#
#                                         pref_name  score  species_group_flag  \
# 0     Breast cancer type 1 susceptibility protein   27.0               False
# 1                         Breast cancer cell line   22.0               False
# 2      STE20-related kinase adapter protein alpha   19.0               False
# 3                      Kinesin-like protein KIF15   19.0               False
# 4      ATP-binding cassette sub-family G member 2   18.0               False
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *STE20-related kinase adapter protein alpha* (third entry)**

# %% [markdown]
# We will assign the third entry (which corresponds to the target protein, *STE20-related kinase adapter protein alpha*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL1795198'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *STE20-related kinase adapter protein alpha* (CHEMBL1795198) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     23372907
# 1        None             None     23373316
# 2        None             None     23373670
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': None, 'result_...   CHEMBL4884872
# 1  [{'comments': None, 'relation': None, 'result_...   CHEMBL4885163
# 2  [{'comments': None, 'relation': None, 'result_...   CHEMBL4885447
#
#                             assay_description assay_type  \
# 0  STLK5(STRAPHD1) Takeda global kinase panel          B
# 1  STLK5(STRAPHD1) Takeda global kinase panel          B
# 2  STLK5(STRAPHD1) Takeda global kinase panel          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('STE20-related kinase adapter protein alpha_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     23372907
# 1        None             None     23373316
# 2        None             None     23373670
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': None, 'result_...   CHEMBL4884872
# 1  [{'comments': None, 'relation': None, 'result_...   CHEMBL4885163
# 2  [{'comments': None, 'relation': None, 'result_...   CHEMBL4885447
#
#                             assay_description assay_type  \
# 0  STLK5(STRAPHD1) Takeda global kinase panel          B
# 1  STLK5(STRAPHD1) Takeda global kinase panel          B
# 2  STLK5(STRAPHD1) Takeda global kinase panel          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 3

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#   action_type activity_comment  activity_id  \
# 0        None             None     23372907
# 1        None             None     23373316
# 2        None             None     23373670
#
#                                  activity_properties assay_chembl_id  \
# 0  [{'comments': None, 'relation': None, 'result_...   CHEMBL4884872
# 1  [{'comments': None, 'relation': None, 'result_...   CHEMBL4885163
# 2  [{'comments': None, 'relation': None, 'result_...   CHEMBL4885447
#
#                             assay_description assay_type  \
# 0  STLK5(STRAPHD1) Takeda global kinase panel          B
# 1  STLK5(STRAPHD1) Takeda global kinase panel          B
# 2  STLK5(STRAPHD1) Takeda global kinase panel          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                    None                   None  BAO_0000190  ...
# 1                    None                   None  BAO_0000190  ...
# 2                    None                   None  BAO_0000190  ...
#
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL4088216  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...
# 1      CHEMBL4549667  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 2      CHEMBL4097778  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
#
#   standard_value
# 0         1000.0
# 1         1000.0
# 2         1000.0

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('STE20-related kinase adapter protein alpha_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('STE20-related kinase adapter protein alpha_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL4088216  CN1C(=O)[C@@H](N2CCc3cn(Cc4ccccc4)nc3C2=O)COc2...
# 1      CHEMBL4549667  CN1C(=O)[C@@H](N2CCc3c(nn(Cc4ccccc4)c3Br)C2=O)...
# 2      CHEMBL4097778  CN1C(=O)[C@@H](N2CCc3cn(CC4CCS(=O)(=O)CC4)nc3C...
#
#    standard_value   class
# 0          1000.0  active
# 1          1000.0  active
# 2          1000.0  active

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('STE20-related kinase adapter protein alpha_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: STE20-related kinase adapter protein alpha_bioactivity_data_curated.csv (deflated 47%)
#   adding: STE20-related kinase adapter protein alpha_bioactivity_data_preprocessed.csv (deflated 45%)
#   adding: STE20-related kinase adapter protein alpha_bioactivity_data_raw.csv (deflated 72%)

# %%
! ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 1993 Feb 23 05:25  acetylcholinesterase.zip
# drwxr-xr-x 1 root root 4096 Feb 20 14:24  sample_data
# -rw-r--r-- 1 root root  315 Feb 23 05:25 'STE20-related kinase adapter protein alpha_bioactivity_data_curated.csv'
# -rw-r--r-- 1 root root  288 Feb 23 05:24 'STE20-related kinase adapter protein alpha_bioactivity_data_preprocessed.csv'
# -rw-r--r-- 1 root root 3008 Feb 23 05:23 'STE20-related kinase adapter protein alpha_bioactivity_data_raw.csv'

# %% [markdown]
# ---
